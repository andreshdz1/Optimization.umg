# %% [markdown]
# <a href="https://colab.research.google.com/github/andreshdz1/Optimization.umg/blob/main/times.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MEASURING OF bigO times
# ###by ANDRES HERNANDEZ
# <p>first im going to declare some libraries and a function to fill an array<p>

# %%
import numpy as np
import matplotlib.pyplot as plt

def random_array(a):
  return np.random.randint(10, size = a)
#example of woking
example = random_array(15)
print(example)
# Out:
# [0 0 0 3 8 1 5 1 4 7 1 7 9 2 3]

# %% [markdown]
# ## the next step is to create function for each O()time
#
#
# *   linear
# *   cuadratic
# *   cubic
# *   cubic plus cuadratic

# %%
def constant(number):
  number +=1

def linear(number):
  for i in number:
    test = i+1

def cuadratic(number):
  for i in number:
    for j in number:
      cuadratic_test = j-i

def cubic(number):
  for i in number:
    for j in number:
      for k in number:
        cubic_test = i+1

def cubicPlus(number):
  cubic(number)
  linear(number)
  linear(number)

# %% [markdown]
# ### next is give the sizes of the array and the space where we are going to save the times for its next comparising

# %%
sizes = [1, 10, 100, 1000]
linearT = []
cuadradicT = []
cubicT = []
cubicPlusT = []

# %% [markdown]
# ### we must check times for each function in order to be able of making graphics from it
# <p>linear<p>

# %%
import time
for i in sizes:
  array = random_array(i)
  begining = time.time()
  linear(array)
  end = time.time()
  total = end - begining
  linearT.append(total)
  print("N: ",i,",  total = ", total)
# Out:
# N:  1 ,  total =  1.1682510375976562e-05
# N:  10 ,  total =  1.2159347534179688e-05
# N:  100 ,  total =  3.1948089599609375e-05
# N:  1000 ,  total =  0.0002319812774658203

# %% [markdown]
# <p>cuadratic<p>

# %%
for i in sizes:
  array = random_array(i)
  begining = time.time()
  cuadratic(array)
  end = time.time()
  total = end - begining
  cuadradicT.append(total)
  print("N: ",i,",  total = ", total)
# Out:
# N:  1 ,  total =  1.5735626220703125e-05
# N:  10 ,  total =  3.5762786865234375e-05
# N:  100 ,  total =  0.0021560192108154297
# N:  1000 ,  total =  0.21509552001953125

# %% [markdown]
# <p>cubic<p>

# %%
for i in sizes:
  array = random_array(i)
  begining = time.time()
  cubic(array)
  end = time.time()
  total = end - begining
  cubicT.append(total)
  print("N: ",i,",  total = ", total)
# Out:
# N:  1 ,  total =  1.4781951904296875e-05
# N:  10 ,  total =  0.00044083595275878906
# N:  100 ,  total =  0.22839856147766113
# N:  1000 ,  total =  153.30554795265198

# %% [markdown]
# <p>Cubic, plus two times linear<p>

# %%
for i in sizes:
  array = random_array(i)
  begining = time.time()
  cubicPlus(array)
  end = time.time()
  total = end - begining
  cubicPlusT.append(total)
  print("N: ",i,",  total = ", total)
# Out:
# N:  1 ,  total =  2.193450927734375e-05
# N:  10 ,  total =  0.0002510547637939453
# N:  100 ,  total =  0.1428544521331787
# N:  1000 ,  total =  140.44641494750977

# %% [markdown]
# ## GRAPHIC OF TIMES
# <p>im going to compare running times, inside of a graphic, you will realize how some times as cubic are deployed on a certain point just so big, in a diference of linear or cuadratic<p>

# %%
plt.plot(sizes, linearT, label='linear')
plt.plot(sizes, cuadradicT, label = 'cuadratic')
plt.plot(sizes, cubicT, label = 'cubic')
plt.plot(sizes, cubicPlusT, label = 'cubic + 2*linear')

# %%
import seaborn as sns
sns.set_theme()

plt.plot(sizes, linearT, c = "r", label = "Linear")

plt.plot(sizes, cuadradicT, c = "b", label = "Cuadratic")

plt.plot(sizes, cubicT, c = "y", label = "Cubic")

plt.plot(sizes, cubicPlusT, c = "g", label = "Cubic + 2n")
plt.xlabel("N")
plt.ylabel("Time in seconds")
plt.title("big O times")
plt.legend()
